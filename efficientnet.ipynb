# %%
from google.colab import drive 
drive.mount('/content/drive')

# %%
import matplotlib.pyplot as plt
from PIL import Image 
import seaborn as sns
import numpy as np
import pandas as pd
import os
from tensorflow.keras.utils import to_categorical
from glob import glob
import cv2
from tensorflow.keras import backend as K

# %%
for dirpath,dirnames,filenames in os.walk("/content/drive/MyDrive/research_tra/main"):
  print(f"There are len{len(dirnames)} directories and {len(filenames)} image in '{dirpath}'.")

# %%
import datetime
def create_tensorboard_callback(dir_name, experiment_name):
  log_dir = dir_name + "/" + experiment_name + "/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
  tensorboard_callback = tf.keras.callbacks.TensorBoard(
      log_dir=log_dir
  )
  print(f"Saving TensorBoard log files to: {log_dir}")
  return tensorboard_callback

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

IMAGE_SHAPE = (224,224)
BATCH_SIZE = 32 

train_dir = 'Train'
test_dir = 'Test'

train_datagen = ImageDataGenerator(rescale=1/255.)
test_datagen = ImageDataGenerator(rescale=1/255.)

print("Training images:")

train_data = train_datagen.flow_from_directory(train_dir,
                                               target_size = IMAGE_SHAPE,
                                               batch_size = BATCH_SIZE,
                                               class_mode="categorical")
print("testing images:")
test_data = test_datagen.flow_from_directory(test_dir,
                                             target_size=IMAGE_SHAPE,
                                             batch_size=BATCH_SIZE,
                                             class_mode="categorical")
# Out:
# Training images:
# Found 15599 images belonging to 7 classes.
# testing images:
# Found 7000 images belonging to 7 classes.

# %%
import tensorflow as tf
import tensorflow_hub as hub
from tensorflow.keras import layers

# %%
efficientnet_url="https://tfhub.dev/tensorflow/efficientnet/b0/feature-vector/1"

# %%
def create_model (model_url,num_classes=7):
  feature_extractor_layer = hub.KerasLayer(model_url,
                                           trainable=True,
                                           name='feature_extraction_layer',
                                           input_shape = IMAGE_SHAPE+(3,))
  model=tf.keras.Sequential([
                             feature_extractor_layer,
                             layers.Dense(num_classes,activation='softmax',name='output_layers')
  ])
  return model

# %%
def mean_iou(y_true, y_pred):
    true_positives=tf.reduce_sum(tf.round(K.clip(y_true*y_pred, 0, 1)))
    true_negatives=tf.reduce_sum(K.round(K.clip((1-y_true)*(1-y_pred), 0, 1)))
    possible_negatives=tf.reduce_sum(K.round(K.clip((1-y_true), 0, 1)))
    possible_positives=tf.reduce_sum(tf.round(K.clip(y_true, 0, 1)))
    iou = (true_positives)/(possible_negatives - true_negatives + possible_positives + K.epsilon())
    return K.mean(iou)  
  
def sensitivity(y_true,y_pred):
    true_positives=tf.reduce_sum(tf.round(K.clip(y_true*y_pred, 0, 1)))
    possible_positives=tf.reduce_sum(tf.round(K.clip(y_true, 0, 1)))
    return true_positives / (possible_positives+K.epsilon())

def specificity(y_true,y_pred):
    true_negatives=tf.reduce_sum(K.round(K.clip((1-y_true)*(1-y_pred), 0, 1)))
    possible_negatives=tf.reduce_sum(K.round(K.clip((1-y_true), 0, 1)))
    return true_negatives / (possible_negatives+K.epsilon())



def precision(y_true, y_pred):
    """ Precision metric. Only computes a batch-wise average of precision. Computes the precision, a metric for multi-label classification of
    how many selected items are relevant."""
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

def recall(y_true, y_pred):
    """ Recall metric. Only computes a batch-wise average of recall. Computes the recall, a metric for multi-label classification of
    how many relevant items are selected. """
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

# %%
efficientnet_model = create_model(efficientnet_url,num_classes = train_data.num_classes)
efficientnet_model.summary()
efficientnet_model.compile(loss='categorical_crossentropy',
                     optimizer=tf.keras.optimizers.Adam(),
                     metrics=['accuracy',sensitivity, precision,recall,specificity])
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  feature_extraction_layer (K  (None, 1280)             4049564
#  erasLayer)
#
#  output_layers (Dense)       (None, 7)                 8967
#
# =================================================================
# Total params: 4,058,531
# Trainable params: 4,016,515
# Non-trainable params: 42,016
# _________________________________________________________________

# %%
efficientnet_history =efficientnet_model.fit(train_data,
                                  epochs=15,
                                  steps_per_epoch=len(train_data),
                                  validation_data=test_data,
                                  validation_steps=len(test_data),
                                  # Add TensorBoard callback to model (callbacks parameter takes a list)
                                  callbacks=[create_tensorboard_callback(dir_name="tensorflow_hub", # save experiment logs here
                                                                         experiment_name="efficientnet_net")])
# Out:
# Saving TensorBoard log files to: tensorflow_hub/efficientnet_net/20220430-215705
# Epoch 1/15
# 488/488 [==============================] - 114s 213ms/step - loss: 0.7723 - accuracy: 0.7739 - sensitivity: 0.7115 - precision: 0.8223 - recall: 0.7115 - specificity: 0.9765 - val_loss: 0.6829 - val_accuracy: 0.8036 - val_sensitivity: 0.7781 - val_precision: 0.8335 - val_recall: 0.7781 - val_specificity: 0.9741
# Epoch 2/15
# 488/488 [==============================] - 103s 210ms/step - loss: 0.4524 - accuracy: 0.8889 - sensitivity: 0.8680 - precision: 0.9084 - recall: 0.8680 - specificity: 0.9854 - val_loss: 0.7551 - val_accuracy: 0.8101 - val_sensitivity: 0.7943 - val_precision: 0.8299 - val_recall: 0.7943 - val_specificity: 0.9729
# Epoch 3/15
# 488/488 [==============================] - 102s 209ms/step - loss: 0.3509 - accuracy: 0.9259 - sensitivity: 0.9172 - precision: 0.9369 - recall: 0.9172 - specificity: 0.9897 - val_loss: 0.5217 - val_accuracy: 0.8670 - val_sensitivity: 0.8525 - val_precision: 0.8782 - val_recall: 0.8525 - val_specificity: 0.9803
# Epoch 4/15
# 488/488 [==============================] - 102s 210ms/step - loss: 0.3067 - accuracy: 0.9417 - sensitivity: 0.9349 - precision: 0.9489 - recall: 0.9349 - specificity: 0.9916 - val_loss: 0.4923 - val_accuracy: 0.8861 - val_sensitivity: 0.8728 - val_precision: 0.9003 - val_recall: 0.8728 - val_specificity: 0.9839
# Epoch 5/15
# 488/488 [==============================] - 99s 202ms/step - loss: 0.2862 - accuracy: 0.9505 - sensitivity: 0.9457 - precision: 0.9560 - recall: 0.9457 - specificity: 0.9927 - val_loss: 0.3967 - val_accuracy: 0.9240 - val_sensitivity: 0.9172 - val_precision: 0.9314 - val_recall: 0.9172 - val_specificity: 0.9887
# Epoch 6/15
# 488/488 [==============================] - 96s 196ms/step - loss: 0.2585 - accuracy: 0.9605 - sensitivity: 0.9570 - precision: 0.9650 - recall: 0.9570 - specificity: 0.9942 - val_loss: 0.4372 - val_accuracy: 0.9106 - val_sensitivity: 0.9043 - val_precision: 0.9168 - val_recall: 0.9043 - val_specificity: 0.9863
# Epoch 7/15
# 488/488 [==============================] - 98s 200ms/step - loss: 0.2561 - accuracy: 0.9642 - sensitivity: 0.9613 - precision: 0.9672 - recall: 0.9613 - specificity: 0.9946 - val_loss: 0.4839 - val_accuracy: 0.8970 - val_sensitivity: 0.8922 - val_precision: 0.9029 - val_recall: 0.8922 - val_specificity: 0.9840
# Epoch 8/15
# 488/488 [==============================] - 101s 208ms/step - loss: 0.2453 - accuracy: 0.9661 - sensitivity: 0.9643 - precision: 0.9686 - recall: 0.9643 - specificity: 0.9948 - val_loss: 0.5746 - val_accuracy: 0.8757 - val_sensitivity: 0.8708 - val_precision: 0.8844 - val_recall: 0.8708 - val_specificity: 0.9810
# Epoch 9/15
# 488/488 [==============================] - 102s 209ms/step - loss: 0.2345 - accuracy: 0.9721 - sensitivity: 0.9704 - precision: 0.9741 - recall: 0.9704 - specificity: 0.9957 - val_loss: 0.5078 - val_accuracy: 0.8991 - val_sensitivity: 0.8941 - val_precision: 0.9045 - val_recall: 0.8941 - val_specificity: 0.9843
# Epoch 10/15
# 488/488 [==============================] - 101s 208ms/step - loss: 0.2302 - accuracy: 0.9724 - sensitivity: 0.9703 - precision: 0.9743 - recall: 0.9703 - specificity: 0.9957 - val_loss: 0.4939 - val_accuracy: 0.8979 - val_sensitivity: 0.8946 - val_precision: 0.9022 - val_recall: 0.8946 - val_specificity: 0.9838
# Epoch 11/15
# 488/488 [==============================] - 102s 209ms/step - loss: 0.2267 - accuracy: 0.9742 - sensitivity: 0.9726 - precision: 0.9761 - recall: 0.9726 - specificity: 0.9960 - val_loss: 0.4475 - val_accuracy: 0.9266 - val_sensitivity: 0.9234 - val_precision: 0.9327 - val_recall: 0.9234 - val_specificity: 0.9889
# Epoch 12/15
# 488/488 [==============================] - 102s 209ms/step - loss: 0.2222 - accuracy: 0.9765 - sensitivity: 0.9753 - precision: 0.9780 - recall: 0.9753 - specificity: 0.9963 - val_loss: 0.6065 - val_accuracy: 0.8814 - val_sensitivity: 0.8777 - val_precision: 0.8872 - val_recall: 0.8777 - val_specificity: 0.9814
# Epoch 13/15
# 488/488 [==============================] - 101s 207ms/step - loss: 0.2181 - accuracy: 0.9771 - sensitivity: 0.9763 - precision: 0.9787 - recall: 0.9763 - specificity: 0.9965 - val_loss: 0.5133 - val_accuracy: 0.9094 - val_sensitivity: 0.9056 - val_precision: 0.9139 - val_recall: 0.9056 - val_specificity: 0.9858
# Epoch 14/15
# 488/488 [==============================] - 102s 210ms/step - loss: 0.2239 - accuracy: 0.9754 - sensitivity: 0.9745 - precision: 0.9767 - recall: 0.9745 - specificity: 0.9961 - val_loss: 0.4707 - val_accuracy: 0.9146 - val_sensitivity: 0.9104 - val_precision: 0.9199 - val_recall: 0.9104 - val_specificity: 0.9868
# Epoch 15/15
# 488/488 [==============================] - 103s 212ms/step - loss: 0.2053 - accuracy: 0.9813 - sensitivity: 0.9803 - precision: 0.9825 - recall: 0.9803 - specificity: 0.9971 - val_loss: 0.4410 - val_accuracy: 0.9273 - val_sensitivity: 0.9253 - val_precision: 0.9308 - val_recall: 0.9253 - val_specificity: 0.9885

# %%
tf.keras.models.save_model(efficientnet_model, 'efficientnet_model.h5')

# %%
fig, axs = plt.subplots(1, 2, figsize = (15, 4))

training_loss = efficientnet_history.history['loss']
validation_loss = efficientnet_history.history['val_loss']

training_accuracy = efficientnet_history.history['accuracy']
validation_accuracy = efficientnet_history.history['val_accuracy']

epoch_count = range(1, len(training_loss) + 1)

axs[0].plot(epoch_count, training_loss, 'r--')
axs[0].plot(epoch_count, validation_loss, 'b-')
axs[0].legend(['Training Loss', 'Validation Loss'])

axs[1].plot(epoch_count, training_accuracy, 'r--')
axs[1].plot(epoch_count, validation_accuracy, 'b-')
axs[1].legend(['Training Accuracy', 'Validation Accuracy'])

# %%
fig, axs = plt.subplots(1, 2, figsize = (15, 4))

training_recall = efficientnet_history.history['recall']
validation_recall = efficientnet_history.history['val_recall']
training_precision = efficientnet_history.history['precision']
validation_precision =efficientnet_history.history['val_precision']

epoch_count = range(1, len(training_loss) + 1)

axs[0].plot(epoch_count, training_recall, 'r--')
axs[0].plot(epoch_count, validation_recall, 'b-')
axs[0].legend(['Training recall', 'Validation recall'])

axs[1].plot(epoch_count, training_precision, 'r--')
axs[1].plot(epoch_count, validation_precision, 'b-')
axs[1].legend(['Training precision', 'Validation precision'])

# %%
fig, axs = plt.subplots(1, 2, figsize = (15, 4))

training_mean_iou = efficientnet_history.history['sensitivity']
validation_mean_iou =  efficientnet_history.history['val_sensitivity']

training_specificity =  efficientnet_history.history['specificity']
validation_specificity =  efficientnet_history.history['val_specificity']

epoch_count = range(1, len(training_loss) + 1)

axs[0].plot(epoch_count, training_mean_iou, 'r--')
axs[0].plot(epoch_count, validation_mean_iou, 'b-')
axs[0].legend(['Training sensitivity', 'Validation sensitivity'])

axs[1].plot(epoch_count, training_specificity, 'r--')
axs[1].plot(epoch_count, validation_specificity, 'b-')
axs[1].legend(['Training specificity', 'Validation specificity'])
